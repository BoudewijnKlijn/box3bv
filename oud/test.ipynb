# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=list("abc"), dtype=int)
df.loc[0, "a"] = 1
df.loc[1, 'a'] = df.loc[0, "a"]
df.loc[1, 'a'] += 2

df
# Out:
#      a   b   c
# 0  1.0 NaN NaN
# 1  3.0 NaN NaN
